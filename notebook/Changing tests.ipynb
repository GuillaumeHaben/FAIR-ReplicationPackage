# %%
import pandas as pd
data = pd.read_json('dataset.35past.Linux.json')
data.shape
# Out:
# (185035, 22)

# %%
import numpy as np
from pprint import pprint
from collections import Counter
# CLEAN DATA

# Keep flaky failures and legit failures only
data = data[((data["flakeRate"] == 0) & (data["label"] == 1)) | (data["label"] == 0)]
# data = data.drop(data[((data['flakeRate'] == 0) & (data["label"] == 0))].sample(frac=.95).index)

# Drop test duplicates
# data = data.drop_duplicates(subset=["testId", "label"])
data = data.replace([np.inf, -np.inf], np.nan).dropna(axis=1)

data.reset_index(drop=True, inplace=True)
print(Counter(data["label"]))
data.shape
# Out:
# Counter({0: 182989, 1: 1274})
# (184263, 22)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.preprocessing import OneHotEncoder, KBinsDiscretizer, Binarizer

# Columns definition
testSource_col = "testSource"
stackTrace_col = "stackTrace"
command_col = "command"
stderr_col = "stderr"
crashlog_col = "crashlog"
cat_cols = ["runStatus", "runTagStatus", "testSuite"]
bin_cols = ["percentageDiffDuration"]
std_cols = ["flakeRate"]
other_cols = ["runDuration"]

# Columns transformers
cols_trans = ColumnTransformer([
    ('categories', OneHotEncoder(handle_unknown = "ignore"), cat_cols),
    ('testSource', TfidfVectorizer(), testSource_col),
    ], remainder='passthrough')

# %%
# Split Train and Test set
from sklearn.model_selection import train_test_split

dataTrain = data
dataTest = data

dataTrain = dataTrain[(((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98022)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98038)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98050)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98079)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98115)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98135)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98150)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98160)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98198)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98217)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98254)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98258)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98267)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98294)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98298)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98320)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98325)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98326)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98328)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98344)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98350)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98352)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98380)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98411)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98463)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98482)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98504)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98530)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98533)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98563)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98586)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98596)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98612)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98631)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98641)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98654)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98659)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98670)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98683)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98689)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98898)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") | (data["buildId"] != 98935)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98024)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98060)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98080)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98087)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98122)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98129)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98147)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98291)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98327)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98435)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98466)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98494)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98497)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98507)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98551)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98752)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98816)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98823)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98851)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98890)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") | (data["buildId"] != 98959)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98025)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98111)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98121)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98249)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98250)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98262)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98329)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98429)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98461)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98463)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98545)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98552)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98664)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98670)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98686)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98696)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98697)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98708)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98737)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98751)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98815)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98831)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98845)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98887)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98892)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98978)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98979)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98980)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98981)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98026)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98032)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98052)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98060)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98073)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98076)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98081)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98102)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98107)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98108)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98111)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98132)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98144)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98176)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98200)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98201)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98204)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98209)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98215)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98231)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98246)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98247)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98264)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98274)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98297)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98300)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98326)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98328)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98336)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98367)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98371)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98409)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98410)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98417)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98419)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98422)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98442)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98444)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98483)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98504)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98505)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98506)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98521)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98524)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98527)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98530)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98539)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98607)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98637)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98641)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98665)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98667)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98679)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98689)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98705)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98708)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98720)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98729)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98741)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98753)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98757)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98769)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98771)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98792)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98799)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98825)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98848)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98852)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98880)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98908)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98910)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98916)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98937)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98944)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") | (data["buildId"] != 98945)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") | (data["buildId"] != 98029)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") | (data["buildId"] != 98153)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") | (data["buildId"] != 98278)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") | (data["buildId"] != 98321)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") | (data["buildId"] != 98393)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") | (data["buildId"] != 98400)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") | (data["buildId"] != 98438)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") | (data["buildId"] != 98537)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") | (data["buildId"] != 98621)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") | (data["buildId"] != 98710)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") | (data["buildId"] != 98778)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") | (data["buildId"] != 98794)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") | (data["buildId"] != 98936)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") | (data["buildId"] != 98035)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") | (data["buildId"] != 98040)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") | (data["buildId"] != 98136)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") | (data["buildId"] != 98253)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") | (data["buildId"] != 98324)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") | (data["buildId"] != 98365)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") | (data["buildId"] != 98374)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") | (data["buildId"] != 98428)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") | (data["buildId"] != 98463)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") | (data["buildId"] != 98499)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98043)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98065)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98089)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98119)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98137)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98147)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98160)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98161)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98171)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98194)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98202)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98213)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98216)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98217)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98219)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98240)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98259)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98262)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98279)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98284)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98309)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98336)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98346)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98359)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98390)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98417)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98425)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98427)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98428)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98435)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98440)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98457)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98491)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98537)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98539)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98544)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98554)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98556)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98561)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98580)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98634)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98667)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98693)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98701)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98752)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98753)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98772)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98794)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98798)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98808)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98818)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98832)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98846)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98897)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") | (data["buildId"] != 98930)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") | (data["buildId"] != 98055)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") | (data["buildId"] != 98075)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") | (data["buildId"] != 98154)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") | (data["buildId"] != 98227)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") | (data["buildId"] != 98251)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") | (data["buildId"] != 98432)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") | (data["buildId"] != 98508)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") | (data["buildId"] != 98637)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") | (data["buildId"] != 98718)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") | (data["buildId"] != 98740)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") | (data["buildId"] != 98798)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98071)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98077)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98089)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98093)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98098)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98126)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98261)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98304)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98316)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98404)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98415)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98430)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98447)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98452)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98538)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98545)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98551)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98552)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98638)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98640)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98743)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98784)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98789)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98798)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98824)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98847)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98850)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98868)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98920)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98978)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98979)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98980)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") | (data["buildId"] != 98981)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") | (data["buildId"] != 98087)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") | (data["buildId"] != 98097)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") | (data["buildId"] != 98098)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") | (data["buildId"] != 98100)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") | (data["buildId"] != 98107)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") | (data["buildId"] != 98111)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") | (data["buildId"] != 98114)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") | (data["buildId"] != 98115)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") | (data["buildId"] != 98118)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") | (data["buildId"] != 98125)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") | (data["buildId"] != 98131)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") | (data["buildId"] != 98138)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") | (data["buildId"] != 98145)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") | (data["buildId"] != 98153)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") | (data["buildId"] != 98155)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") | (data["buildId"] != 98157)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/PrerenderBrowserTest.IndexedDBAccess/All.WebContents") | (data["buildId"] != 98152)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/PrerenderBrowserTest.IndexedDBAccess/All.WebContents") | (data["buildId"] != 98156)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SystemWebAppManagerBackgroundTaskTest.TimerFires/All._Default") | (data["buildId"] != 98198)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SystemWebAppManagerBackgroundTaskTest.TimerFires/All._Default") | (data["buildId"] != 98970)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SystemWebAppManagerBackgroundTaskTest.TimerFires/All._Default") | (data["buildId"] != 98971)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/SystemWebAppManagerBackgroundTaskTest.TimerFires/All._Default") | (data["buildId"] != 98973)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98230)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98265)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98291)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98331)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98375)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98394)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98457)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98482)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98640)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98655)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98668)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98691)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98719)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98738)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98811)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98892)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98897)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98902)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") | (data["buildId"] != 98942)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") | (data["buildId"] != 98241)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") | (data["buildId"] != 98343)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") | (data["buildId"] != 98381)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") | (data["buildId"] != 98521)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") | (data["buildId"] != 98607)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") | (data["buildId"] != 98709)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") | (data["buildId"] != 98755)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") | (data["buildId"] != 98757)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") | (data["buildId"] != 98769)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") | (data["buildId"] != 98773)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") | (data["buildId"] != 98897)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") | (data["buildId"] != 98945)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") | (data["buildId"] != 98981)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-strokeRect-gradient-shadow.html") | (data["buildId"] != 98258)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-strokeRect-gradient-shadow.html") | (data["buildId"] != 98265)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-strokeRect-gradient-shadow.html") | (data["buildId"] != 98395)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-strokeRect-gradient-shadow.html") | (data["buildId"] != 98446)) & 
((dataTrain["testId"] != "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-strokeRect-gradient-shadow.html") | (data["buildId"] != 98936)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/CommerceHintAgentTest.CartPriority") | (data["buildId"] != 98259)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/CommerceHintAgentTest.CartPriority") | (data["buildId"] != 98303)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") | (data["buildId"] != 98294)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") | (data["buildId"] != 98322)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") | (data["buildId"] != 98351)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") | (data["buildId"] != 98372)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") | (data["buildId"] != 98392)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") | (data["buildId"] != 98428)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") | (data["buildId"] != 98470)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") | (data["buildId"] != 98506)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") | (data["buildId"] != 98607)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") | (data["buildId"] != 98633)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") | (data["buildId"] != 98654)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") | (data["buildId"] != 98715)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") | (data["buildId"] != 98756)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") | (data["buildId"] != 98802)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") | (data["buildId"] != 98822)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") | (data["buildId"] != 98842)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") | (data["buildId"] != 98898)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98363)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98364)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98365)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98366)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98371)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98372)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98373)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98374)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98375)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98379)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98380)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98383)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98385)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98387)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98390)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98392)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98394)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98395)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98399)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98400)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") | (data["buildId"] != 98401)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") | (data["buildId"] != 98394)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") | (data["buildId"] != 98672)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") | (data["buildId"] != 98923)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") | (data["buildId"] != 98924)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") | (data["buildId"] != 98929)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") | (data["buildId"] != 98930)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") | (data["buildId"] != 98932)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") | (data["buildId"] != 98940)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") | (data["buildId"] != 98943)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") | (data["buildId"] != 98447)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") | (data["buildId"] != 98448)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") | (data["buildId"] != 98449)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") | (data["buildId"] != 98450)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") | (data["buildId"] != 98451)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") | (data["buildId"] != 98452)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") | (data["buildId"] != 98783)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") | (data["buildId"] != 98878)) & 
((dataTrain["testId"] != "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") | (data["buildId"] != 98941)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerNtpModuleTest.TestDisableFakeData") | (data["buildId"] != 98489)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerNtpModuleTest.TestDisableFakeData") | (data["buildId"] != 98493)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerNtpModuleTest.TestDisableFakeData") | (data["buildId"] != 98506)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerNtpModuleTest.TestDisableFakeData") | (data["buildId"] != 98513)) & 
((dataTrain["testId"] != "unit_tests_ninja://chrome/test:unit_tests/CartHandlerNtpModuleTest.TestDisableFakeData") | (data["buildId"] != 98518)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/PageLoadMetricsBrowserTest.MainFrameIntersectionCrossOrigin") | (data["buildId"] != 98801)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/PageLoadMetricsBrowserTest.MainFrameIntersectionCrossOrigin") | (data["buildId"] != 98803)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/PageLoadMetricsBrowserTest.MainFrameIntersectionCrossOrigin") | (data["buildId"] != 98822)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/PageLoadMetricsBrowserTest.MainFrameIntersectionCrossOrigin") | (data["buildId"] != 98825)) & 
((dataTrain["testId"] != "weblayer_browsertests_ninja://weblayer/test:weblayer_browsertests/AdsPageLoadMetricsObserverBrowserTest.OriginStatusMetricCross") | (data["buildId"] != 98805)) & 
((dataTrain["testId"] != "weblayer_browsertests_ninja://weblayer/test:weblayer_browsertests/AdsPageLoadMetricsObserverBrowserTest.OriginStatusMetricCross") | (data["buildId"] != 98808)) & 
((dataTrain["testId"] != "weblayer_browsertests_ninja://weblayer/test:weblayer_browsertests/AdsPageLoadMetricsObserverBrowserTest.OriginStatusMetricCross") | (data["buildId"] != 98810)) & 
((dataTrain["testId"] != "weblayer_browsertests_ninja://weblayer/test:weblayer_browsertests/AdsPageLoadMetricsObserverBrowserTest.OriginStatusMetricCross") | (data["buildId"] != 98813)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/AutofillInteractiveTest.DynamicFormFill") | (data["buildId"] != 98816)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/AutofillInteractiveTest.DynamicFormFill") | (data["buildId"] != 98929)) & 
((dataTrain["testId"] != "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/AutofillInteractiveTest.DynamicFormFill") | (data["buildId"] != 98965)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/PrerenderBrowserTest.DeferCrossOriginRedirectsOnSubframeNavigation/All.WebContents") | (data["buildId"] != 98827)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/PrerenderBrowserTest.DeferCrossOriginRedirectsOnSubframeNavigation/All.WebContents") | (data["buildId"] != 98868)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/PrerenderBrowserTest.DeferCrossOriginRedirectsOnSubframeNavigation/All.WebContents") | (data["buildId"] != 98872)) & 
((dataTrain["testId"] != "content_browsertests_ninja://content/test:content_browsertests/PrerenderBrowserTest.DeferCrossOriginRedirectsOnSubframeNavigation/All.WebContents") | (data["buildId"] != 98887)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/ReferrerPolicyTest.RequestTabletSite") | (data["buildId"] != 98832)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/ReferrerPolicyTest.RequestTabletSite") | (data["buildId"] != 98833)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/WebNavigationApiTest.TargetBlank") | (data["buildId"] != 98832)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/WebNavigationApiTest.TargetBlank") | (data["buildId"] != 98918)) & 
((dataTrain["testId"] != "browser_tests_ninja://chrome/test:browser_tests/WebNavigationApiTest.TargetBlank") | (data["buildId"] != 98919))
)]

dataTest = dataTest[(((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98022)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98038)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98050)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98079)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98115)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98135)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98150)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98160)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98198)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98217)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98254)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98258)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98267)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98294)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98298)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98320)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98325)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98326)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98328)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98344)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98350)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98352)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98380)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98411)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98463)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98482)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98504)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98530)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98533)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98563)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98586)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98596)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98612)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98631)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98641)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98654)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98659)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98670)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98683)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98689)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98898)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/AutoplayPolicyTest.AutoplayWhitelist_Missing") & (dataTest["buildId"] == 98935)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98024)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98060)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98080)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98087)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98122)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98129)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98147)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98291)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98327)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98435)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98466)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98494)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98497)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98507)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98551)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98752)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98816)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98823)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98851)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98890)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SubresourceRedirectLoginRobotsBrowserTest.TestImageLoadAfterRobotsFetch") & (dataTest["buildId"] == 98959)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98025)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98111)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98121)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98249)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98250)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98262)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98329)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98429)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98461)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98463)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98545)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98552)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98664)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98670)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98686)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98696)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98697)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98708)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98737)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98751)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98815)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98831)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98845)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98887)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98892)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98978)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98979)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98980)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98981)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98026)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98032)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98052)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98060)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98073)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98076)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98081)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98102)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98107)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98108)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98111)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98132)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98144)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98176)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98200)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98201)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98204)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98209)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98215)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98231)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98246)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98247)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98264)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98274)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98297)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98300)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98326)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98328)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98336)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98367)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98371)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98409)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98410)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98417)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98419)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98422)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98442)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98444)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98483)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98504)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98505)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98506)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98521)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98524)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98527)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98530)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98539)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98607)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98637)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98641)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98665)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98667)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98679)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98689)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98705)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98708)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98720)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98729)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98741)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98753)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98757)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98769)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98771)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98792)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98799)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98825)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98848)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98852)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98880)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98908)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98910)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98916)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98937)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98944)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DragGroupHeaderToSeparateWindow/TabDragging.0") & (dataTest["buildId"] == 98945)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") & (dataTest["buildId"] == 98029)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") & (dataTest["buildId"] == 98153)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") & (dataTest["buildId"] == 98278)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") & (dataTest["buildId"] == 98321)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") & (dataTest["buildId"] == 98393)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") & (dataTest["buildId"] == 98400)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") & (dataTest["buildId"] == 98438)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") & (dataTest["buildId"] == 98537)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") & (dataTest["buildId"] == 98621)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") & (dataTest["buildId"] == 98710)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") & (dataTest["buildId"] == 98778)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") & (dataTest["buildId"] == 98794)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-text.html") & (dataTest["buildId"] == 98936)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") & (dataTest["buildId"] == 98035)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") & (dataTest["buildId"] == 98040)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") & (dataTest["buildId"] == 98136)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") & (dataTest["buildId"] == 98253)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") & (dataTest["buildId"] == 98324)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") & (dataTest["buildId"] == 98365)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") & (dataTest["buildId"] == 98374)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") & (dataTest["buildId"] == 98428)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") & (dataTest["buildId"] == 98463)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/wheel-event-regions/fast/events/platform-wheelevent-paging-xy-in-scrolling-div.html") & (dataTest["buildId"] == 98499)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98043)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98065)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98089)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98119)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98137)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98147)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98160)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98161)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98171)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98194)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98202)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98213)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98216)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98217)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98219)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98240)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98259)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98262)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98279)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98284)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98309)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98336)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98346)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98359)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98390)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98417)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98425)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98427)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98428)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98435)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98440)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98457)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98491)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98537)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98539)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98544)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98554)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98556)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98561)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98580)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98634)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98667)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98693)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98701)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98752)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98753)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98772)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98794)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98798)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98808)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98818)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98832)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98846)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98897)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/PrefetchManagerTest.StopAndStart") & (dataTest["buildId"] == 98930)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") & (dataTest["buildId"] == 98055)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") & (dataTest["buildId"] == 98075)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") & (dataTest["buildId"] == 98154)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") & (dataTest["buildId"] == 98227)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") & (dataTest["buildId"] == 98251)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") & (dataTest["buildId"] == 98432)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") & (dataTest["buildId"] == 98508)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") & (dataTest["buildId"] == 98637)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") & (dataTest["buildId"] == 98718)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") & (dataTest["buildId"] == 98740)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-blending-fill-style.html") & (dataTest["buildId"] == 98798)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98071)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98077)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98089)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98093)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98098)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98126)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98261)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98304)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98316)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98404)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98415)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98430)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98447)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98452)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98538)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98545)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98551)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98552)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98638)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98640)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98743)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98784)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98789)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98798)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98824)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98847)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98850)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98868)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98920)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98978)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98979)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98980)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/layers/layer-canvas-log.js") & (dataTest["buildId"] == 98981)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") & (dataTest["buildId"] == 98087)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") & (dataTest["buildId"] == 98097)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") & (dataTest["buildId"] == 98098)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") & (dataTest["buildId"] == 98100)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") & (dataTest["buildId"] == 98107)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") & (dataTest["buildId"] == 98111)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") & (dataTest["buildId"] == 98114)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") & (dataTest["buildId"] == 98115)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") & (dataTest["buildId"] == 98118)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") & (dataTest["buildId"] == 98125)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") & (dataTest["buildId"] == 98131)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") & (dataTest["buildId"] == 98138)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") & (dataTest["buildId"] == 98145)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") & (dataTest["buildId"] == 98153)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") & (dataTest["buildId"] == 98155)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerTest.TestDisableFakeData") & (dataTest["buildId"] == 98157)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/PrerenderBrowserTest.IndexedDBAccess/All.WebContents") & (dataTest["buildId"] == 98152)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/PrerenderBrowserTest.IndexedDBAccess/All.WebContents") & (dataTest["buildId"] == 98156)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SystemWebAppManagerBackgroundTaskTest.TimerFires/All._Default") & (dataTest["buildId"] == 98198)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SystemWebAppManagerBackgroundTaskTest.TimerFires/All._Default") & (dataTest["buildId"] == 98970)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SystemWebAppManagerBackgroundTaskTest.TimerFires/All._Default") & (dataTest["buildId"] == 98971)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/SystemWebAppManagerBackgroundTaskTest.TimerFires/All._Default") & (dataTest["buildId"] == 98973)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98230)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98265)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98291)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98331)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98375)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98394)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98457)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98482)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98640)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98655)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98668)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98691)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98719)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98738)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98811)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98892)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98897)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98902)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/MediaSessionPictureInPictureWindowControllerBrowserTest.NextTrackHandlerCalled") & (dataTest["buildId"] == 98942)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") & (dataTest["buildId"] == 98241)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") & (dataTest["buildId"] == 98343)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") & (dataTest["buildId"] == 98381)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") & (dataTest["buildId"] == 98521)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") & (dataTest["buildId"] == 98607)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") & (dataTest["buildId"] == 98709)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") & (dataTest["buildId"] == 98755)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") & (dataTest["buildId"] == 98757)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") & (dataTest["buildId"] == 98769)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") & (dataTest["buildId"] == 98773)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") & (dataTest["buildId"] == 98897)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") & (dataTest["buildId"] == 98945)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/DetachToBrowserTabDragControllerTest.DetachToOwnWindowFromMaximizedWindow/TabDragging.0") & (dataTest["buildId"] == 98981)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-strokeRect-gradient-shadow.html") & (dataTest["buildId"] == 98258)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-strokeRect-gradient-shadow.html") & (dataTest["buildId"] == 98265)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-strokeRect-gradient-shadow.html") & (dataTest["buildId"] == 98395)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-strokeRect-gradient-shadow.html") & (dataTest["buildId"] == 98446)) | 
((dataTest["testId"] == "blink_web_tests_ninja://:blink_web_tests/virtual/gpu/fast/canvas/canvas-strokeRect-gradient-shadow.html") & (dataTest["buildId"] == 98936)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/CommerceHintAgentTest.CartPriority") & (dataTest["buildId"] == 98259)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/CommerceHintAgentTest.CartPriority") & (dataTest["buildId"] == 98303)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") & (dataTest["buildId"] == 98294)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") & (dataTest["buildId"] == 98322)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") & (dataTest["buildId"] == 98351)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") & (dataTest["buildId"] == 98372)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") & (dataTest["buildId"] == 98392)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") & (dataTest["buildId"] == 98428)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") & (dataTest["buildId"] == 98470)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") & (dataTest["buildId"] == 98506)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") & (dataTest["buildId"] == 98607)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") & (dataTest["buildId"] == 98633)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") & (dataTest["buildId"] == 98654)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") & (dataTest["buildId"] == 98715)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") & (dataTest["buildId"] == 98756)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") & (dataTest["buildId"] == 98802)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") & (dataTest["buildId"] == 98822)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") & (dataTest["buildId"] == 98842)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/ServiceWorkerV8CodeCacheForCacheStorageBadOriginTest.V8CacheOnCacheStorage") & (dataTest["buildId"] == 98898)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98363)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98364)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98365)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98366)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98371)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98372)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98373)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98374)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98375)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98379)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98380)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98383)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98385)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98387)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98390)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98392)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98394)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98395)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98399)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98400)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/virtual/webrtc-wpt-plan-b/external/wpt/webrtc/RTCRtpTransceiver.https.html") & (dataTest["buildId"] == 98401)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") & (dataTest["buildId"] == 98394)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") & (dataTest["buildId"] == 98672)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") & (dataTest["buildId"] == 98923)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") & (dataTest["buildId"] == 98924)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") & (dataTest["buildId"] == 98929)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") & (dataTest["buildId"] == 98930)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") & (dataTest["buildId"] == 98932)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") & (dataTest["buildId"] == 98940)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/HostedOrWebAppTest.CtrlClickLink/All.WebApp") & (dataTest["buildId"] == 98943)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") & (dataTest["buildId"] == 98447)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") & (dataTest["buildId"] == 98448)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") & (dataTest["buildId"] == 98449)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") & (dataTest["buildId"] == 98450)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") & (dataTest["buildId"] == 98451)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") & (dataTest["buildId"] == 98452)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") & (dataTest["buildId"] == 98783)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") & (dataTest["buildId"] == 98878)) | 
((dataTest["testId"] == "not_site_per_process_blink_web_tests_ninja://:blink_web_tests/http/tests/devtools/oopif/oopif-elements-navigate-out.js") & (dataTest["buildId"] == 98941)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerNtpModuleTest.TestDisableFakeData") & (dataTest["buildId"] == 98489)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerNtpModuleTest.TestDisableFakeData") & (dataTest["buildId"] == 98493)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerNtpModuleTest.TestDisableFakeData") & (dataTest["buildId"] == 98506)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerNtpModuleTest.TestDisableFakeData") & (dataTest["buildId"] == 98513)) | 
((dataTest["testId"] == "unit_tests_ninja://chrome/test:unit_tests/CartHandlerNtpModuleTest.TestDisableFakeData") & (dataTest["buildId"] == 98518)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/PageLoadMetricsBrowserTest.MainFrameIntersectionCrossOrigin") & (dataTest["buildId"] == 98801)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/PageLoadMetricsBrowserTest.MainFrameIntersectionCrossOrigin") & (dataTest["buildId"] == 98803)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/PageLoadMetricsBrowserTest.MainFrameIntersectionCrossOrigin") & (dataTest["buildId"] == 98822)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/PageLoadMetricsBrowserTest.MainFrameIntersectionCrossOrigin") & (dataTest["buildId"] == 98825)) | 
((dataTest["testId"] == "weblayer_browsertests_ninja://weblayer/test:weblayer_browsertests/AdsPageLoadMetricsObserverBrowserTest.OriginStatusMetricCross") & (dataTest["buildId"] == 98805)) | 
((dataTest["testId"] == "weblayer_browsertests_ninja://weblayer/test:weblayer_browsertests/AdsPageLoadMetricsObserverBrowserTest.OriginStatusMetricCross") & (dataTest["buildId"] == 98808)) | 
((dataTest["testId"] == "weblayer_browsertests_ninja://weblayer/test:weblayer_browsertests/AdsPageLoadMetricsObserverBrowserTest.OriginStatusMetricCross") & (dataTest["buildId"] == 98810)) | 
((dataTest["testId"] == "weblayer_browsertests_ninja://weblayer/test:weblayer_browsertests/AdsPageLoadMetricsObserverBrowserTest.OriginStatusMetricCross") & (dataTest["buildId"] == 98813)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/AutofillInteractiveTest.DynamicFormFill") & (dataTest["buildId"] == 98816)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/AutofillInteractiveTest.DynamicFormFill") & (dataTest["buildId"] == 98929)) | 
((dataTest["testId"] == "interactive_ui_tests_ninja://chrome/test:interactive_ui_tests/AutofillInteractiveTest.DynamicFormFill") & (dataTest["buildId"] == 98965)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/PrerenderBrowserTest.DeferCrossOriginRedirectsOnSubframeNavigation/All.WebContents") & (dataTest["buildId"] == 98827)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/PrerenderBrowserTest.DeferCrossOriginRedirectsOnSubframeNavigation/All.WebContents") & (dataTest["buildId"] == 98868)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/PrerenderBrowserTest.DeferCrossOriginRedirectsOnSubframeNavigation/All.WebContents") & (dataTest["buildId"] == 98872)) | 
((dataTest["testId"] == "content_browsertests_ninja://content/test:content_browsertests/PrerenderBrowserTest.DeferCrossOriginRedirectsOnSubframeNavigation/All.WebContents") & (dataTest["buildId"] == 98887)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/ReferrerPolicyTest.RequestTabletSite") & (dataTest["buildId"] == 98832)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/ReferrerPolicyTest.RequestTabletSite") & (dataTest["buildId"] == 98833)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/WebNavigationApiTest.TargetBlank") & (dataTest["buildId"] == 98832)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/WebNavigationApiTest.TargetBlank") & (dataTest["buildId"] == 98918)) | 
((dataTest["testId"] == "browser_tests_ninja://chrome/test:browser_tests/WebNavigationApiTest.TargetBlank") & (dataTest["buildId"] == 98919))
)]

print(len(data))
print(len(dataTrain))
print(len(dataTest))
# pprint(dataTest)

X_train = dataTrain[cat_cols + other_cols + std_cols + [testSource_col]]
y_train = dataTrain['label']

X_test = dataTest[cat_cols + other_cols + std_cols + [testSource_col]]
y_test = dataTest['label']

# pprint(dataTest)
# print("Train set:")
# print(Counter(y_train))

# print("Test set:")
# print(Counter(y_test))
# Out:
# 184263
# 183739
# 524

# %%
from numpy import mean
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier 
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest, chi2, SelectFromModel
from sklearn.model_selection import cross_validate, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import precision_score, recall_score, f1_score, matthews_corrcoef
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from sklearn import set_config
set_config(display="diagram")
from sklearn.base import TransformerMixin, BaseEstimator
from imblearn.ensemble import BalancedRandomForestClassifier 

# Pipeline
over = RandomOverSampler(sampling_strategy=0.1)
under = RandomUnderSampler(sampling_strategy=1)
smote = SMOTE(sampling_strategy=1)
featureSelection = SelectFromModel(RandomForestClassifier(n_estimators=100, random_state=2))
rfc = BalancedRandomForestClassifier(n_estimators=100)
adasyn = ADASYN()

steps = [
    ('trans', cols_trans),
#     ('s', smote), 
    ('m', rfc)
]
pipe = Pipeline(steps=steps)
display(pipe)
# Out:
# Pipeline(steps=[('trans',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('categories',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['runStatus', 'runTagStatus',
#                                                    'testSuite']),
#                                                  ('testSource',
#                                                   TfidfVectorizer(),
#                                                   'testSource')])),
#                 ('m', BalancedRandomForestClassifier())])

# %%
# Model
pipe.fit(X_train, y_train)

# Test best estimator on holdout set
y_pred = pipe.predict(X_test)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
mcc = matthews_corrcoef(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("\nPrecision", precision)
print("Recall", recall)
print("MCC", mcc)
print("F1", f1)
# Out:
# Precision 0.46153846153846156
# Recall 0.582089552238806
# MCC 0.32549860707554457
# F1 0.5148514851485149
